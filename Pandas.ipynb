# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmeda335/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a DataFrame.

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns = ["A", "B", "C"])
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# # Information and description of the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 200.0 bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df.nunique()  # Getting number of elements for each row.
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['B'].unique()  # Getting the elements of the column specified.
# Out:
# array([2, 5, 8])

# %% [markdown]
# # Playing with indexes.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()  # showing the normal indexs in a list.
# Out:
# [0, 1, 2]

# %%
df_indexed = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns = ["A", "B", "C"], index = ["a", "b", "c"])
df_indexed
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
df_indexed = df_indexed.set_index("A")  # Setting the column 'A' as the index.

# %%
df_indexed
# Out:
#    B  C
# A
# 1  2  3
# 4  5  6
# 7  8  9

# %%
df_indexed.index
# Out:
# Index([1, 4, 7], dtype='int64', name='A')

# %%
df_indexed.reset_index()  # Resetting the index.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# # Displaying the data.

# %%
df.head()  # showing the first '5' rows.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head(2)  # showing the first '2' rows.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df.tail()  # showing the last '5' rows.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.tail(2)  # showing the last '2' rows.
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
display(df.sample(2))  # Getting '2' random data.
display(df.sample(2, random_state=200))  # This will give me the same random data unless I change number '200'.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# # Accessing the Data

# %%
display(df.loc[[1, 2], ["B", "C"]])  # It is in the shape 'loc[columns, rows]'
display(df.loc[0:2, ['A', 'B']])

display(df.iloc[[1, 2], [0, 1]])  # It is in the shape 'iloc[rows, columns]' but in indexes.
display(df.iloc[0:2, [0, 1]])
# Out:
#    B  C
# 1  5  6
# 2  8  9
#    A  B
# 0  1  2
# 1  4  5
# 2  7  8
#    A  B
# 1  4  5
# 2  7  8
#    A  B
# 0  1  2
# 1  4  5

# %%
# Changing the value of a cell
df.loc[1, 'A'] = 44
df
# Out:
#     A  B  C
# 0   1  2  3
# 1  44  5  6
# 2   7  8  9

# %%
df.at[0, "A"]
df.iat[1, 1]
# Out:
# 5

# %%
# Grapping Columns
display(df['A'])
display(df.A)
display(type(df['A']))
# Out:
# 0     1
# 1    44
# 2     7
# Name: A, dtype: int64
# 0     1
# 1    44
# 2     7
# Name: A, dtype: int64
# pandas.core.series.Series

# %%
# Sorting the rows
df.sort_values('A', ascending=False)
# Out:
#     A  B  C
# 1  44  5  6
# 2   7  8  9
# 0   1  2  3

# %%
# Iterating over the rows using for loop.
for index, row in df.iterrows():
  print(index)
  print(row)
  print('\n\n\n')
# Out:
# 0
# A    1
# B    2
# C    3
# Name: 0, dtype: int64
#
#
#
#
# 1
# A    44
# B     5
# C     6
# Name: 1, dtype: int64
#
#
#
#
# 2
# A    7
# B    8
# C    9
# Name: 2, dtype: int64

# %% [markdown]
# # Filtering the Data.

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head(10)
# Out:
#                              name   born_date          born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12           Bordeaux
# 2                  Arnaud Boetsch  1969-04-01             Meulan
# 3                    Jean Borotra  1898-08-13           Biarritz
# 4                 Jacques Brugnon  1895-05-11        Paris VIIIe
# 5                    Albert Canet  1878-04-17         Wandsworth
# 6               Nicolas Chatelain  1970-01-13             Amiens
# 7                   Patrick Chila  1969-11-27        Ris-Orangis
# 8                    Henri Cochet  1901-12-14       Villeurbanne
# 9                   Marcel Cousin  1896-08-04              Nîmes
# 10             Guy de la Chapelle  1868-07-16  Farges-Allichamps
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
# 6                          Somme          FRA  France      181.0       70.0
# 7                        Essonne          FRA  France      180.0       73.0
# 8                          Rhône          FRA  France        NaN        NaN
# 9                           Gard          FRA  France        NaN        NaN
# 10                          Cher          FRA  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25
# 6                  NaN
# 7                  NaN
# 8           1987-04-02
# 9           1986-08-01
# 10          1923-08-27

# %%
display(athlete.loc[athlete['height_cm'] > 180, ['name', 'height_cm']].head())  # If I want to specify columns, I use 'loc'.
display(athlete[athlete['height_cm'] > 180].head())   # Here, I didn't use 'loc' but I can't specify columns.
# Out:
#                          name  height_cm
# athlete_id
# 2              Arnaud Boetsch      183.0
# 3                Jean Borotra      183.0
# 6           Nicolas Chatelain      181.0
# 17                 Guy Forget      189.0
# 26              Henri Leconte      184.0
#                          name   born_date   born_city           born_region  \
# athlete_id
# 2              Arnaud Boetsch  1969-04-01      Meulan              Yvelines
# 3                Jean Borotra  1898-08-13    Biarritz  Pyrénées-Atlantiques
# 6           Nicolas Chatelain  1970-01-13      Amiens                 Somme
# 17                 Guy Forget  1965-01-04  Casablanca     Casablanca-Settat
# 26              Henri Leconte  1963-07-04     Lillers         Pas-de-Calais
#
#            born_country     NOC  height_cm  weight_kg   died_date
# athlete_id
# 2                   FRA  France      183.0       76.0         NaN
# 3                   FRA  France      183.0       76.0  1994-07-17
# 6                   FRA  France      181.0       70.0         NaN
# 17                  MAR  France      189.0       79.0         NaN
# 26                  FRA  France      184.0       78.0         NaN

# %%
athlete.loc[athlete['height_cm'] > 180].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35368 entries, 2 to 149221
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          35368 non-null  object
#  1   born_date     35359 non-null  object
#  2   born_city     30082 non-null  object
#  3   born_region   30082 non-null  object
#  4   born_country  30082 non-null  object
#  5   NOC           35368 non-null  object
#  6   height_cm     35368 non-null  float64
#  7   weight_kg     33882 non-null  float64
#  8   died_date     4583 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 2.7+ MB

# %%
# Using Two conditions

athlete.loc[(athlete['height_cm'] > 180) & (athlete['weight_kg'] > 90), ['name', 'height_cm', 'weight_kg']].head()
# Out:
#                             name  height_cm  weight_kg
# athlete_id
# 519               Detlef Kahlert      184.0       92.0
# 526         Bernhard Schulkowski      195.0      105.0
# 634           Mark Philippoussis      193.0       91.0
# 651                 Karl Jindrak      185.0       98.0
# 797         Árni Þór Hallgrímson      192.0       97.0

# %%
# Displaying the string values which contain specific characters. Using (Regex)

display(athlete.loc[athlete.name.str.contains("Ahmed")].sample(5, random_state=200))
display(athlete.loc[athlete.name.str.contains("AHMED", case=False)].sample(5, random_state=200))  # When I put 'case=False' It is not case sensetive now. 'AHMED' like 'ahmed'

# Getting cities that starts with vowels
display(athlete.loc[athlete.born_city.str.contains(r'^[AEIOUaeiou]', na=False)].sample(5))

# Find athletes with names ending with 'son' or 'sen'
display(athlete.loc[athlete.name.str.contains(r'son$|sen$', case=False, na=False)].sample(5))

# Find athletes with names has repeated letters like 'ahmmad'.
display(athlete.loc[athlete.name.str.contains(r'(.)\1', na=False)].sample(5))

# If I want to stop the (Regex) search.
display(athlete.loc[athlete.name.str.contains('AHMED', case=False, regex=False)].sample(5))
# Out:
#                     name   born_date          born_city        born_region  \
# athlete_id
# 19972       Bashir Ahmed  1934-12-23            Karachi              Sindh
# 124613        Ahmed Awad  1987-01-01                NaN                NaN
# 129923       Samia Ahmed  1996-01-20  Al-Qahira (Cairo)          Al-Qahira
# 66574       Ahmed Douhou  1976-12-14             Bouaké  Vallée du Bandama
# 31583        Ahmed Debes  1970-01-14                NaN                NaN
#
#            born_country                   NOC  height_cm  weight_kg died_date
# athlete_id
# 19972               PAK              Pakistan      171.0       67.0       NaN
# 124613              NaN                 Egypt      165.0       66.0       NaN
# 129923              EGY                 Egypt      170.0       57.0       NaN
# 66574               CIV  Côte d'Ivoire France      190.0       94.0       NaN
# 31583               NaN                 Egypt        NaN        NaN       NaN
#                     name   born_date          born_city        born_region  \
# athlete_id
# 19972       Bashir Ahmed  1934-12-23            Karachi              Sindh
# 124613        Ahmed Awad  1987-01-01                NaN                NaN
# 129923       Samia Ahmed  1996-01-20  Al-Qahira (Cairo)          Al-Qahira
# 66574       Ahmed Douhou  1976-12-14             Bouaké  Vallée du Bandama
# 31583        Ahmed Debes  1970-01-14                NaN                NaN
#
#            born_country                   NOC  height_cm  weight_kg died_date
# athlete_id
# 19972               PAK              Pakistan      171.0       67.0       NaN
# 124613              NaN                 Egypt      165.0       66.0       NaN
# 129923              EGY                 Egypt      170.0       57.0       NaN
# 66574               CIV  Côte d'Ivoire France      190.0       94.0       NaN
# 31583               NaN                 Egypt        NaN        NaN       NaN
#                               name   born_date        born_city born_region  \
# athlete_id
# 70771       Andreas Kouvelogiannis  1939-03-07  Athina (Athens)      Attiki
# 10628                  Mihai Zafiu  1949-06-09          Albești    Botoșani
# 114912        Anastasiya Pilipenko  1986-09-13           Almaty      Almaty
# 68697                  Ann Johnson  1933-09-28            Elham     England
# 88586                Adolf Koxeder  1934-10-09        Innsbruck       Tirol
#
#            born_country            NOC  height_cm  weight_kg died_date
# athlete_id
# 70771               GRE         Greece      178.0       80.0       NaN
# 10628               ROU        Romania      187.0       87.0       NaN
# 114912              KAZ     Kazakhstan      174.0       55.0       NaN
# 68697               GBR  Great Britain      175.0       64.0       NaN
# 88586               AUT        Austria      180.0       85.0       NaN
#                              name   born_date               born_city  \
# athlete_id
# 87572              Arne Johansson  1915-02-25                Enköping
# 11983       Harry Freeman-Jackson  1910-12-23              Rawalpindi
# 112001          Therese Helgesson  1983-07-22               Stockholm
# 66938            Julius Jørgensen  1880-06-20  København (Copenhagen)
# 52061                 Jorge Edson  1966-10-13            Porto Alegre
#
#                   born_region born_country      NOC  height_cm  weight_kg  \
# athlete_id
# 87572                 Uppsala          SWE   Sweden        NaN        NaN
# 11983                  Punjab          PAK  Ireland      175.0       63.0
# 112001              Stockholm          SWE   Sweden      172.0       64.0
# 66938             Hovedstaden          DEN  Denmark        NaN        NaN
# 52061       Rio Grande do Sul          BRA   Brazil      192.0       90.0
#
#              died_date
# athlete_id
# 87572       1956-10-12
# 11983       1993-07-21
# 112001             NaN
# 66938       1937-10-03
# 52061              NaN
# <ipython-input-270-38de836f4d68>:13: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   display(athlete.loc[athlete.name.str.contains(r'(.)\1', na=False)].sample(5))
#                               name   born_date        born_city  \
# athlete_id
# 90885               Tracey Wheeler  1967-09-26           Sydney
# 25263                    Bill Neil  1939-05-22          Airdrie
# 52397       Gabriella Csapó-Fekete  1954-08-23      Nyíregyháza
# 126388               Elise Chabbey  1993-04-24  Genève (Geneva)
# 31680             Philippe Gardent  1964-03-15       Belleville
#
#                        born_region born_country            NOC  height_cm  \
# athlete_id
# 90885              New South Wales          AUS      Australia      180.0
# 25263                     Scotland          GBR  Great Britain      183.0
# 52397       Szabolcs-Szatmár-Bereg          HUN        Hungary      176.0
# 126388                      Genève          SUI    Switzerland      164.0
# 31680                        Rhône          FRA         France      184.0
#
#             weight_kg   died_date
# athlete_id
# 90885            74.0         NaN
# 25263            73.0  2014-09-22
# 52397            61.0  2023-06-19
# 126388           56.0         NaN
# 31680            98.0         NaN
#                              name   born_date born_city        born_region  \
# athlete_id
# 66574                Ahmed Douhou  1976-12-14    Bouaké  Vallée du Bandama
# 29733        Ahmed Amin Tabouzada         NaN       NaN                NaN
# 13322       Jamal Ahmed Al-Doseri  1970-01-01       NaN                NaN
# 52736                 Ahmed Zoubi         NaN       NaN                NaN
# 52729             Ahmed El-Faghei         NaN       NaN                NaN
#
#            born_country                   NOC  height_cm  weight_kg died_date
# athlete_id
# 66574               CIV  Côte d'Ivoire France      190.0       94.0       NaN
# 29733               NaN                 Egypt        NaN        NaN       NaN
# 13322               NaN               Bahrain      155.0       70.0       NaN
# 52736               NaN                 Libya        NaN        NaN       NaN
# 52729               NaN                 Libya        NaN        NaN       NaN

# %%
# using 'isin' function.

display(athlete.loc[athlete.born_country.isin(['EGY'])].sample(5))

display(athlete.loc[athlete.born_country.isin(["EGy"]) & athlete.name.str.contains(r"m")])
# Out:
#                             name   born_date                    born_city  \
# athlete_id
# 53705       Ibrahim Abdel Rahman  1940-01-01            Al-Qahira (Cairo)
# 67088             Ibrahim Okasha  1911-01-01            Al-Qahira (Cairo)
# 24793         Mohamed Reda Hamad  1939-11-09            Al-Qahira (Cairo)
# 1848                Kabary Salem  1968-02-12  Al-Iskanderiya (Alexandria)
# 67067              Mahmoud Attef  1938-01-01            Al-Qahira (Cairo)
#
#                born_region born_country                   NOC  height_cm  \
# athlete_id
# 53705            Al-Qahira          EGY  United Arab Republic        NaN
# 67088            Al-Qahira          EGY                 Egypt        NaN
# 24793            Al-Qahira          EGY                 Egypt        NaN
# 1848        Al-Iskanderiya          EGY                 Egypt        NaN
# 67067            Al-Qahira          EGY  United Arab Republic        NaN
#
#             weight_kg died_date
# athlete_id
# 53705             NaN       NaN
# 67088             NaN       NaN
# 24793             NaN       NaN
# 1848              NaN       NaN
# 67067             NaN       NaN
# Empty DataFrame
# Columns: [name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %% [markdown]
# # Applying on an existance file. 'Coffee Shop.csv'

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
coffee
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(1)
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 464.0+ bytes

# %%
coffee.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
coffee.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold'], dtype='object')

# %%
coffee.sort_values('Units Sold')
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values('Units Sold', ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
display(coffee.sort_values(['Units Sold', 'Coffee Type'], ascending=[0, 1]))
display(coffee.sort_values(['Units Sold', 'Coffee Type'], ascending=[1, 0]))
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in coffee.iterrows():
  print(index)
  print(row)
  print('\n\n\n')
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
#
#
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
#
#
#
#
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
#
#
#
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
#
#
#
#
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
#
#
#
#
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object

# %%
coffee.nunique()  # Getting number of unique elements for each column.
# Out:
# Day            7
# Coffee Type    2
# Units Sold     7
# dtype: int64

# %%
coffee['Coffee Type'].unique()
# Out:
# array(['Espresso', 'Latte'], dtype=object)

# %%
coffee_excel = coffee.to_excel('coffee.xlsx')  # Converting the file to excel file.

# %% [markdown]
# # Applying on an existance file. 'Athletics.csv'

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
athlete.tail()
# Out:
#                            name   born_date        born_city      born_region  \
# athlete_id
# 149222        Polina Luchnikova  2002-01-30            Serov       Sverdlovsk
# 149223      Valeriya Merkusheva  1999-09-20  Moskva (Moscow)           Moskva
# 149224          Yuliya Smirnova  1998-05-08           Kotlas      Arkhangelsk
# 149225           André Foussard  1899-05-19            Niort      Deux-Sèvres
# 149814            Bill Phillips  1913-07-15     Dulwich Hill  New South Wales
#
#            born_country        NOC  height_cm  weight_kg   died_date
# athlete_id
# 149222              RUS        ROC      167.0       61.0         NaN
# 149223              RUS        ROC      168.0       65.0         NaN
# 149224              RUS        ROC      163.0       55.0         NaN
# 149225              FRA     France      166.0        NaN  1986-03-18
# 149814              AUS  Australia        NaN        NaN  2003-10-20

# %%
display(athlete.sample(5))  # Gettnig a random '10' samples.
display(athlete.sample(5, random_state=122))  # This will print the same rows unless I change the number '122'.
# Out:
#                          name   born_date   born_city born_region  \
# athlete_id
# 23637           Juan Paladino  1925-02-17  Montevideo  Montevideo
# 89064       Ruslan Hlivinskyi  1975-02-07         NaN         NaN
# 112780        Alexis Chiclana  1987-02-02         NaN         NaN
# 113072          Sara Mustonen  1981-02-08     Höganäs       Skåne
# 5892            Yaya Cissokho  1955-01-24         NaN         NaN
#
#            born_country          NOC  height_cm  weight_kg died_date
# athlete_id
# 23637               URU      Uruguay      185.0       95.0       NaN
# 89064               NaN      Ukraine      204.0       82.0       NaN
# 112780              NaN  Puerto Rico      180.0       86.0       NaN
# 113072              SWE       Sweden      161.0       58.0       NaN
# 5892                NaN      Senegal      196.0       87.0       NaN
#                          name   born_date      born_city born_region  \
# athlete_id
# 58157             Eddie Bowey  1928-01-05         London     England
# 65816               Jane Bell  1910-06-02        Toronto     Ontario
# 26145       Beniamino Vignola  1959-06-12         Verona      Verona
# 66053         Lionel Fournier  1917-03-19  Pincher Creek     Alberta
# 97498        Hiroyasu Shimizu  1974-02-27        Obihiro    Hokkaido
#
#            born_country            NOC  height_cm  weight_kg   died_date
# athlete_id
# 58157               GBR  Great Britain        NaN        NaN  2016-01-01
# 65816               CAN         Canada      169.0       58.0  1998-07-01
# 26145               ITA          Italy      172.0       64.0         NaN
# 66053               CAN         Canada        NaN        NaN  1993-09-03
# 97498               JPN          Japan      162.0       70.0         NaN

# %%
display(athlete.loc[[1, 2, 3]])
display(athlete.loc[1:6])
display(athlete.loc[[1, 2, 3], ['name']])
display(athlete.loc[[1, 2, 3], ['name', 'born_city']])

display(athlete.iloc[[0, 1, 2], [0, 1, 2]])
display(athlete.iloc[1:3, 0:3])
# Out:
#                              name   born_date born_city           born_region  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12  Bordeaux               Gironde
# 2                  Arnaud Boetsch  1969-04-01    Meulan              Yvelines
# 3                    Jean Borotra  1898-08-13  Biarritz  Pyrénées-Atlantiques
#
#            born_country     NOC  height_cm  weight_kg   died_date
# athlete_id
# 1                   FRA  France        NaN        NaN  1960-10-02
# 2                   FRA  France      183.0       76.0         NaN
# 3                   FRA  France      183.0       76.0  1994-07-17
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
# 6               Nicolas Chatelain  1970-01-13       Amiens
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
# 6                          Somme          FRA  France      181.0       70.0
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25
# 6                  NaN
#                              name
# athlete_id
# 1           Jean-François Blanchy
# 2                  Arnaud Boetsch
# 3                    Jean Borotra
#                              name born_city
# athlete_id
# 1           Jean-François Blanchy  Bordeaux
# 2                  Arnaud Boetsch    Meulan
# 3                    Jean Borotra  Biarritz
#                              name   born_date born_city
# athlete_id
# 1           Jean-François Blanchy  1886-12-12  Bordeaux
# 2                  Arnaud Boetsch  1969-04-01    Meulan
# 3                    Jean Borotra  1898-08-13  Biarritz
#                       name   born_date born_city
# athlete_id
# 2           Arnaud Boetsch  1969-04-01    Meulan
# 3             Jean Borotra  1898-08-13  Biarritz

# %%
athlete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145500 entries, 1 to 149814
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          145500 non-null  object
#  1   born_date     143693 non-null  object
#  2   born_city     110908 non-null  object
#  3   born_region   110908 non-null  object
#  4   born_country  110908 non-null  object
#  5   NOC           145499 non-null  object
#  6   height_cm     106651 non-null  float64
#  7   weight_kg     102070 non-null  float64
#  8   died_date     33940 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 15.1+ MB

# %%
athlete.describe()
# Out:
#            height_cm      weight_kg
# count  106651.000000  102070.000000
# mean      176.333724      71.890996
# std        10.380282      14.465540
# min       127.000000      25.000000
# 25%       170.000000      62.000000
# 50%       176.000000      70.000000
# 75%       183.000000      80.000000
# max       226.000000     198.000000

# %% [markdown]
# # Applying on an existance file. 'results.parquet'

# %%
# olympics_results = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.parquet')   # Can't be decoded because it is large.
# olympics_results.head()
