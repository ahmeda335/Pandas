# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmeda335/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a DataFrame.

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns = ["A", "B", "C"])
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df_indexed = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns = ["A", "B", "C"], index = ["a", "b", "c"])
df_indexed
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
# Copying to another dataframe.
coffee = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv")

# %%
coffee_new = coffee
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee_new['price'] = 6
display(coffee_new.head())
display(coffee.head())

# Here we note that both 'coffee' and 'coffee_new' has the column 'price' because this kind of copy
# is stored in the memory of pandas as a single memory, so any change in one of the dataframe will change
# the other also.
# To solve this we use hard copy --> '.copy()'

coffee.drop(columns = 'price', inplace=True)
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25      6
# 1     Monday       Latte          15      6
# 2    Tuesday    Espresso          30      6
# 3    Tuesday       Latte          20      6
# 4  Wednesday    Espresso          35      6
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25      6
# 1     Monday       Latte          15      6
# 2    Tuesday    Espresso          30      6
# 3    Tuesday       Latte          20      6
# 4  Wednesday    Espresso          35      6

# %%
coffee_new = coffee.copy()
coffee_new['price'] = 6
display(coffee_new.head())
display(coffee.head())
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25      6
# 1     Monday       Latte          15      6
# 2    Tuesday    Espresso          30      6
# 3    Tuesday       Latte          20      6
# 4  Wednesday    Espresso          35      6
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# # Information and description of the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 200.0 bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df.nunique()  # Getting number of elements for each column.
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['B'].unique()  # Getting the elements of the column specified.
# Out:
# array([2, 5, 8])

# %% [markdown]
# # Playing with indexes.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()  # showing the normal indexs in a list.
# Out:
# [0, 1, 2]

# %%
df_indexed = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns = ["A", "B", "C"], index = ["a", "b", "c"])
df_indexed
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
df_indexed = df_indexed.set_index("A")  # Setting the column 'A' as the index.

# %%
df_indexed
# Out:
#    B  C
# A
# 1  2  3
# 4  5  6
# 7  8  9

# %%
df_indexed.index
# Out:
# Index([1, 4, 7], dtype='int64', name='A')

# %%
df_indexed.reset_index()  # Resetting the index.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# # Displaying the data.

# %%
df.head()  # showing the first '5' rows.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head(2)  # showing the first '2' rows.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df.tail()  # showing the last '5' rows.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.tail(2)  # showing the last '2' rows.
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
display(df.sample(2))  # Getting '2' random data.
display(df.sample(2, random_state=200))  # This will give me the same random data unless I change number '200'.
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# # Accessing the Data

# %%
display(df.loc[[1, 2], ["B", "C"]])  # It is in the shape 'loc[rows, columns]'
display(df.loc[0:2, ['A', 'B']])

display(df.iloc[[1, 2], [0, 1]])  # It is in the shape 'iloc[rows, columns]' but in indexes.
display(df.iloc[0:2, [0, 1]])
# Out:
#    B  C
# 1  5  6
# 2  8  9
#    A  B
# 0  1  2
# 1  4  5
# 2  7  8
#    A  B
# 1  4  5
# 2  7  8
#    A  B
# 0  1  2
# 1  4  5

# %%
# Changing the value of a cell
df.loc[1, 'A'] = 44
df
# Out:
#     A  B  C
# 0   1  2  3
# 1  44  5  6
# 2   7  8  9

# %%
df.at[0, "A"]
df.iat[1, 1]
# Out:
# 5

# %%
# Grapping Columns
display(df['A'])
display(df.A)
display(type(df['A']))
# Out:
# 0     1
# 1    44
# 2     7
# Name: A, dtype: int64
# 0     1
# 1    44
# 2     7
# Name: A, dtype: int64
# pandas.core.series.Series

# %%
# Sorting the rows
df.sort_values('A', ascending=False)
# Out:
#     A  B  C
# 1  44  5  6
# 2   7  8  9
# 0   1  2  3

# %%
# Iterating over the rows using for loop.
for index, row in df.iterrows():
  print(index)
  print(row)
  print('\n\n\n')
# Out:
# 0
# A    1
# B    2
# C    3
# Name: 0, dtype: int64
#
#
#
#
# 1
# A    44
# B     5
# C     6
# Name: 1, dtype: int64
#
#
#
#
# 2
# A    7
# B    8
# C    9
# Name: 2, dtype: int64

# %% [markdown]
# # Filtering the Data.

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head(10)
# Out:
#                              name   born_date          born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12           Bordeaux
# 2                  Arnaud Boetsch  1969-04-01             Meulan
# 3                    Jean Borotra  1898-08-13           Biarritz
# 4                 Jacques Brugnon  1895-05-11        Paris VIIIe
# 5                    Albert Canet  1878-04-17         Wandsworth
# 6               Nicolas Chatelain  1970-01-13             Amiens
# 7                   Patrick Chila  1969-11-27        Ris-Orangis
# 8                    Henri Cochet  1901-12-14       Villeurbanne
# 9                   Marcel Cousin  1896-08-04              Nîmes
# 10             Guy de la Chapelle  1868-07-16  Farges-Allichamps
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
# 6                          Somme          FRA  France      181.0       70.0
# 7                        Essonne          FRA  France      180.0       73.0
# 8                          Rhône          FRA  France        NaN        NaN
# 9                           Gard          FRA  France        NaN        NaN
# 10                          Cher          FRA  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25
# 6                  NaN
# 7                  NaN
# 8           1987-04-02
# 9           1986-08-01
# 10          1923-08-27

# %%
display(athlete.loc[athlete['height_cm'] > 180, ['name', 'height_cm']].head())  # If I want to specify columns, I use 'loc'.
display(athlete[athlete['height_cm'] > 180].head())   # Here, I didn't use 'loc' but I can't specify columns.
# Out:
#                          name  height_cm
# athlete_id
# 2              Arnaud Boetsch      183.0
# 3                Jean Borotra      183.0
# 6           Nicolas Chatelain      181.0
# 17                 Guy Forget      189.0
# 26              Henri Leconte      184.0
#                          name   born_date   born_city           born_region  \
# athlete_id
# 2              Arnaud Boetsch  1969-04-01      Meulan              Yvelines
# 3                Jean Borotra  1898-08-13    Biarritz  Pyrénées-Atlantiques
# 6           Nicolas Chatelain  1970-01-13      Amiens                 Somme
# 17                 Guy Forget  1965-01-04  Casablanca     Casablanca-Settat
# 26              Henri Leconte  1963-07-04     Lillers         Pas-de-Calais
#
#            born_country     NOC  height_cm  weight_kg   died_date
# athlete_id
# 2                   FRA  France      183.0       76.0         NaN
# 3                   FRA  France      183.0       76.0  1994-07-17
# 6                   FRA  France      181.0       70.0         NaN
# 17                  MAR  France      189.0       79.0         NaN
# 26                  FRA  France      184.0       78.0         NaN

# %%
athlete.loc[athlete['height_cm'] > 180].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35368 entries, 2 to 149221
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          35368 non-null  object
#  1   born_date     35359 non-null  object
#  2   born_city     30082 non-null  object
#  3   born_region   30082 non-null  object
#  4   born_country  30082 non-null  object
#  5   NOC           35368 non-null  object
#  6   height_cm     35368 non-null  float64
#  7   weight_kg     33882 non-null  float64
#  8   died_date     4583 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 2.7+ MB

# %%
# Using Two conditions

athlete.loc[(athlete['height_cm'] > 180) & (athlete['weight_kg'] > 90), ['name', 'height_cm', 'weight_kg']].head()
# Out:
#                             name  height_cm  weight_kg
# athlete_id
# 519               Detlef Kahlert      184.0       92.0
# 526         Bernhard Schulkowski      195.0      105.0
# 634           Mark Philippoussis      193.0       91.0
# 651                 Karl Jindrak      185.0       98.0
# 797         Árni Þór Hallgrímson      192.0       97.0

# %%
# Displaying the string values which contain specific characters. Using (Regex)

display(athlete.loc[athlete.name.str.contains("Ahmed")].sample(5, random_state=200))
display(athlete.loc[athlete.name.str.contains("AHMED", case=False)].sample(5, random_state=200))  # When I put 'case=False' It is not case sensetive now. 'AHMED' like 'ahmed'

# Getting cities that starts with vowels
display(athlete.loc[athlete.born_city.str.contains(r'^[AEIOUaeiou]', na=False)].sample(5))

# Find athletes with names ending with 'son' or 'sen'
display(athlete.loc[athlete.name.str.contains(r'son$|sen$', case=False, na=False)].sample(5))

# Find athletes with names has repeated letters like 'ahmmad'.
display(athlete.loc[athlete.name.str.contains(r'(.)\1', na=False)].sample(5))

# If I want to stop the (Regex) search.
display(athlete.loc[athlete.name.str.contains('AHMED', case=False, regex=False)].sample(5))
# Out:
#                     name   born_date          born_city        born_region  \
# athlete_id
# 19972       Bashir Ahmed  1934-12-23            Karachi              Sindh
# 124613        Ahmed Awad  1987-01-01                NaN                NaN
# 129923       Samia Ahmed  1996-01-20  Al-Qahira (Cairo)          Al-Qahira
# 66574       Ahmed Douhou  1976-12-14             Bouaké  Vallée du Bandama
# 31583        Ahmed Debes  1970-01-14                NaN                NaN
#
#            born_country                   NOC  height_cm  weight_kg died_date
# athlete_id
# 19972               PAK              Pakistan      171.0       67.0       NaN
# 124613              NaN                 Egypt      165.0       66.0       NaN
# 129923              EGY                 Egypt      170.0       57.0       NaN
# 66574               CIV  Côte d'Ivoire France      190.0       94.0       NaN
# 31583               NaN                 Egypt        NaN        NaN       NaN
#                     name   born_date          born_city        born_region  \
# athlete_id
# 19972       Bashir Ahmed  1934-12-23            Karachi              Sindh
# 124613        Ahmed Awad  1987-01-01                NaN                NaN
# 129923       Samia Ahmed  1996-01-20  Al-Qahira (Cairo)          Al-Qahira
# 66574       Ahmed Douhou  1976-12-14             Bouaké  Vallée du Bandama
# 31583        Ahmed Debes  1970-01-14                NaN                NaN
#
#            born_country                   NOC  height_cm  weight_kg died_date
# athlete_id
# 19972               PAK              Pakistan      171.0       67.0       NaN
# 124613              NaN                 Egypt      165.0       66.0       NaN
# 129923              EGY                 Egypt      170.0       57.0       NaN
# 66574               CIV  Côte d'Ivoire France      190.0       94.0       NaN
# 31583               NaN                 Egypt        NaN        NaN       NaN
#                          name   born_date     born_city  \
# athlete_id
# 103726      Anriette Schoeman  1977-08-25  Aliwal North
# 13134            Barbara Heeb  1969-02-13     Appenzell
# 43631        Carlos Lastarria  1918-08-27      Arequipa
# 54481           Johan Aantjes  1958-05-06       Utrecht
# 111124            Jacky Moucq  1922-03-11         Uccle
#
#                              born_region born_country           NOC  \
# athlete_id
# 103726                      Eastern Cape          RSA  South Africa
# 13134              Appenzell Innerrhoden          SUI   Switzerland
# 43631                           Arequipa          PER          Peru
# 54481                            Utrecht          NED   Netherlands
# 111124      Région de Bruxelles-Capitale          BEL       Belgium
#
#             height_cm  weight_kg   died_date
# athlete_id
# 103726          158.0       50.0         NaN
# 13134           164.0       51.0         NaN
# 43631           178.0      104.0  1987-10-19
# 54481             NaN        NaN         NaN
# 111124            NaN        NaN  2008-01-01
#                      name   born_date    born_city        born_region  \
# athlete_id
# 100320        Phil Wilson  1965-09-14     Dumfries           Scotland
# 5280        Tammy Jackson  1962-12-03  Gainesville            Florida
# 36568         Ove Nielsen  1924-11-15      Skærbæk         Syddanmark
# 129873       Nanna Madsen  1994-10-23          NaN                NaN
# 74114        Audun Boysen  1929-05-10      Bjarkøy  Troms og Finnmark
#
#            born_country            NOC  height_cm  weight_kg   died_date
# athlete_id
# 100320              GBR  Great Britain      178.0       83.0         NaN
# 5280                USA  United States      190.0       81.0         NaN
# 36568               DEN        Denmark        NaN        NaN  2008-01-01
# 129873              NaN        Denmark      171.0       67.0         NaN
# 74114               NOR         Norway      181.0       66.0  2000-03-02
# <ipython-input-36-38de836f4d68>:13: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   display(athlete.loc[athlete.name.str.contains(r'(.)\1', na=False)].sample(5))
#                                     name   born_date   born_city  \
# athlete_id
# 128176                    Daan Breeuwsma  1987-12-29  Heerenveen
# 39079              Hans Magnus Grepperud  1958-05-10        Oslo
# 121755      Hanna Drabenia-Tserliukevich  1987-08-15    Starobin
# 51533                          Wally Ris  1924-01-04     Chicago
# 131214                Quinta Steenbergen  1985-04-02     Schagen
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# athlete_id
# 128176          Friesland          NED    Netherlands      181.0       73.0
# 39079                Oslo          NOR         Norway      195.0       87.0
# 121755      Minsk Voblast          BLR        Belarus      153.0       46.0
# 51533            Illinois          USA  United States        NaN        NaN
# 131214      Noord-Holland          NED    Netherlands      189.0       75.0
#
#              died_date
# athlete_id
# 128176             NaN
# 39079              NaN
# 121755             NaN
# 51533       1989-12-25
# 131214             NaN
#                            name   born_date            born_city  \
# athlete_id
# 142313            Ahmed Ramadan  1997-03-23                  NaN
# 65637              Ahmed Hamada  1961-09-18                  NaN
# 92527         Alaa El-Din Ahmed  1980-08-28      Qalyub (Kalyub)
# 43596       Aziz Ahmed Chaudhry  1932-01-01                  NaN
# 125186              Ahmed Magdy  1989-12-09  El-Mahalla El-Kubra
#
#              born_region born_country       NOC  height_cm  weight_kg  \
# athlete_id
# 142313               NaN          NaN     Egypt        NaN        NaN
# 65637                NaN          NaN   Bahrain      183.0       70.0
# 92527         Qalyubiyah          EGY     Egypt      189.0       91.0
# 43596                NaN          NaN  Pakistan        NaN        NaN
# 125186      Al-Gharbiyah          EGY     Egypt      172.0       68.0
#
#            died_date
# athlete_id
# 142313           NaN
# 65637            NaN
# 92527            NaN
# 43596            NaN
# 125186           NaN

# %%
# using 'isin' function.

display(athlete.loc[athlete.born_country.isin(['EGY'])].sample(5))

display(athlete.loc[athlete.born_country.isin(["EGy"]) & athlete.name.str.contains(r"m")])
# Out:
#                              name   born_date                    born_city  \
# athlete_id
# 24750               Shawki Gharib  1959-02-26          El-Mahalla El-Kubra
# 1824        Abdel Moneim El-Gindy  1936-12-01  Al-Iskanderiya (Alexandria)
# 7203                Albert Tadros  1914-08-08            Al-Qahira (Cairo)
# 29730             Ismail Abdallah  1933-01-01            Al-Qahira (Cairo)
# 24824                       Yaken  1934-09-12                        Aswan
#
#                born_region born_country                         NOC  \
# athlete_id
# 24750         Al-Gharbiyah          EGY                       Egypt
# 1824        Al-Iskanderiya          EGY        United Arab Republic
# 7203             Al-Qahira          EGY                       Egypt
# 29730            Al-Qahira          EGY        United Arab Republic
# 24824                Aswan          EGY  Egypt United Arab Republic
#
#             height_cm  weight_kg   died_date
# athlete_id
# 24750             NaN        NaN         NaN
# 1824              NaN        NaN  2011-03-17
# 7203              NaN        NaN  1993-04-04
# 29730             NaN        NaN         NaN
# 24824             NaN        NaN  2012-12-22
# Empty DataFrame
# Columns: [name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
# Quering the data

athlete.query('born_country == "EGY"').head()
# Out:
#                                name   born_date                    born_city  \
# athlete_id
# 186             Avgoustos Zerlentis  1886-11-05  Al-Iskanderiya (Alexandria)
# 1251        Hassan Nour-el-Din Aman  1943-05-07            Al-Qahira (Cairo)
# 1809             Fathi Abdel Rahman  1932-04-16            Al-Qahira (Cairo)
# 1811              Ibrahim Abdrabbou  1925-01-24  Al-Iskanderiya (Alexandria)
# 1812                   Gharib Afifi         NaN            Al-Qahira (Cairo)
#
#                born_region born_country         NOC  height_cm  weight_kg  \
# athlete_id
# 186         Al-Iskanderiya          EGY      Greece        NaN        NaN
# 1251             Al-Qahira          EGY  Chad Egypt      178.0       81.0
# 1809             Al-Qahira          EGY       Egypt        NaN        NaN
# 1811        Al-Iskanderiya          EGY       Egypt        NaN        NaN
# 1812             Al-Qahira          EGY       Egypt        NaN        NaN
#
#              died_date
# athlete_id
# 186         1954-01-01
# 1251               NaN
# 1809               NaN
# 1811               NaN
# 1812        1990-01-01

# %% [markdown]
# # Adding and Removing Columns

# %%
coffee = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# Adding a column
coffee['price'] = 5
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25      5
# 1     Monday       Latte          15      5
# 2    Tuesday    Espresso          30      5
# 3    Tuesday       Latte          20      5
# 4  Wednesday    Espresso          35      5

# %%
# Changin the price of only 'Latte' to 6
coffee.loc[coffee['Coffee Type'] == 'Latte' , 'price'] = 6

# %%
# Droping the column we just made.
display(coffee.drop(columns = ['price']).head())  # Here the change in only view not the data itself.
display(coffee.head())

display(coffee.drop(columns = ['price'], inplace=True))  # Here changes the data itself.
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25      5
# 1     Monday       Latte          15      6
# 2    Tuesday    Espresso          30      5
# 3    Tuesday       Latte          20      6
# 4  Wednesday    Espresso          35      5
# None
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 5

# %%
coffee.rename(columns={'price':'coffee_price'}, inplace = True)  # If I didn't put 'inplace = True', It will change in only the view.
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  coffee_price
# 0     Monday    Espresso          25             5
# 1     Monday       Latte          15             5
# 2    Tuesday    Espresso          30             5
# 3    Tuesday       Latte          20             5
# 4  Wednesday    Espresso          35             5

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
athlete_new = athlete.copy()

# %%
athlete_new['first_name'] = athlete_new.name.str.split(' ').str[0]
athlete_new.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date     first_name
# athlete_id
# 1           1960-10-02  Jean-François
# 2                  NaN         Arnaud
# 3           1994-07-17           Jean
# 4           1978-03-20        Jacques
# 5           1930-07-25         Albert

# %%
athlete_new.query('first_name == "Ahmed"')
# Out:
#                          name   born_date          born_city born_region  \
# athlete_id
# 1813            Ahmed El-Said  1970-04-15  Al-Qahira (Cairo)   Al-Qahira
# 1825           Ahmed El-Gindy  1959-01-21                NaN         NaN
# 1829        Ahmed El-Minabawi  1928-07-21  Al-Qahira (Cairo)   Al-Qahira
# 1831           Ahmed El-Nagar  1964-02-19                NaN         NaN
# 1843              Ahmed Mahir  1941-09-12  Al-Qahira (Cairo)   Al-Qahira
# ...                       ...         ...                ...         ...
# 142342            Ahmed Hamed  1997-06-01                NaN         NaN
# 144119       Ahmed Abdelwahed  1996-05-26               Roma        Roma
# 146090            Ahmed Tijan  1995-04-28             Banjul      Banjul
# 147605         Ahmed Al-Yaari  2000-01-16                NaN         NaN
# 147606            Ahmed Ayash  1994-01-01                NaN         NaN
#
#            born_country    NOC  height_cm  weight_kg died_date first_name
# athlete_id
# 1813                EGY  Egypt        NaN        NaN       NaN      Ahmed
# 1825                NaN  Egypt      178.0       75.0       NaN      Ahmed
# 1829                EGY  Egypt        NaN        NaN       NaN      Ahmed
# 1831                NaN  Egypt      180.0       81.0       NaN      Ahmed
# 1843                EGY  Egypt        NaN        NaN       NaN      Ahmed
# ...                 ...    ...        ...        ...       ...        ...
# 142342              NaN  Egypt        NaN        NaN       NaN      Ahmed
# 144119              ITA  Italy        NaN        NaN       NaN      Ahmed
# 146090              GAM  Qatar      187.0        NaN       NaN      Ahmed
# 147605              NaN  Yemen        NaN        NaN       NaN      Ahmed
# 147606              NaN  Yemen        NaN        NaN       NaN      Ahmed
#
# [208 rows x 10 columns]

# %%
athlete_new['born_date'] = pd.to_datetime(athlete_new['born_date'])

# %%
display(athlete_new.head())
athlete_new.info()
# Out:
#                              name  born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy 1886-12-12     Bordeaux
# 2                  Arnaud Boetsch 1969-04-01       Meulan
# 3                    Jean Borotra 1898-08-13     Biarritz
# 4                 Jacques Brugnon 1895-05-11  Paris VIIIe
# 5                    Albert Canet 1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date     first_name
# athlete_id
# 1           1960-10-02  Jean-François
# 2                  NaN         Arnaud
# 3           1994-07-17           Jean
# 4           1978-03-20        Jacques
# 5           1930-07-25         Albert
# <class 'pandas.core.frame.DataFrame'>
# Index: 145500 entries, 1 to 149814
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          145500 non-null  object
#  1   born_date     143693 non-null  datetime64[ns]
#  2   born_city     110908 non-null  object
#  3   born_region   110908 non-null  object
#  4   born_country  110908 non-null  object
#  5   NOC           145499 non-null  object
#  6   height_cm     106651 non-null  float64
#  7   weight_kg     102070 non-null  float64
#  8   died_date     33940 non-null   object
#  9   first_name    145500 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 12.2+ MB

# %%
athlete_new['born_year'] = athlete_new['born_date'].dt.year
athlete_new.head()
# Out:
#                              name  born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy 1886-12-12     Bordeaux
# 2                  Arnaud Boetsch 1969-04-01       Meulan
# 3                    Jean Borotra 1898-08-13     Biarritz
# 4                 Jacques Brugnon 1895-05-11  Paris VIIIe
# 5                    Albert Canet 1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date     first_name  born_year
# athlete_id
# 1           1960-10-02  Jean-François     1886.0
# 2                  NaN         Arnaud     1969.0
# 3           1994-07-17           Jean     1898.0
# 4           1978-03-20        Jacques     1895.0
# 5           1930-07-25         Albert     1878.0

# %%
athlete_new['is_tall1'] = athlete_new['height_cm'] >= 185

# %%
athlete_new.sample(10, random_state = 210)
# Out:
#                          name  born_date               born_city  \
# athlete_id
# 43325          Homero Laddaga 1941-09-10                     NaN
# 141682             Li Mengwen 1995-03-28                  Suzhou
# 7155                Tiit Sokk 1964-11-15                   Tartu
# 85319        Christof Duffner 1971-12-16  Triberg im Schwarzwald
# 46208         Gabrijela Ujčić 1976-10-02                  Rijeka
# 132080         Lauren Kieffer 1987-06-06            Mount Carmel
# 54427            Yu Seung-Hun 1969-10-09                     NaN
# 112520        Clemens Doppler 1980-09-06  Kirchdorf an der Krems
# 88945       Ekundayo Williams 1977-11-23                     NaN
# 73486        Adolfo Clouthier 1909-03-15                Culiacán
#
#                             born_region born_country  \
# athlete_id
# 43325                               NaN          NaN
# 141682                          Jiangsu          CHN
# 7155                           Tartumaa          EST
# 85319                 Baden-Württemberg          GER
# 46208       Primorsko-goranska županija          CRO
# 132080                         Illinois          USA
# 54427                               NaN          NaN
# 112520                   Oberösterreich          AUT
# 88945                               NaN          NaN
# 73486                           Sinaloa          MEX
#
#                                    NOC  height_cm  weight_kg   died_date  \
# athlete_id
# 43325                           Mexico      172.0       84.0         NaN
# 141682      People's Republic of China        NaN        NaN         NaN
# 7155                      Soviet Union      192.0       99.0         NaN
# 85319                          Germany      184.0       66.0         NaN
# 46208                          Croatia        NaN        NaN         NaN
# 132080                   United States      178.0       68.0         NaN
# 54427                Republic of Korea      176.0       75.0         NaN
# 112520                         Austria      200.0       87.0         NaN
# 88945                     Sierra Leone        NaN        NaN         NaN
# 73486                           Mexico      178.0        NaN  2001-04-12
#
#            first_name  born_year  is_tall1
# athlete_id
# 43325          Homero     1941.0     False
# 141682             Li     1995.0     False
# 7155             Tiit     1964.0      True
# 85319        Christof     1971.0     False
# 46208       Gabrijela     1976.0     False
# 132080         Lauren     1987.0     False
# 54427              Yu     1969.0     False
# 112520        Clemens     1980.0      True
# 88945        Ekundayo     1977.0     False
# 73486          Adolfo     1909.0     False

# %%
athlete_new['is_tall2'] = athlete_new['height_cm'].apply(lambda x: 'Tall' if x > 185 else ('Average' if x > 170 else 'Short'))

# %%
athlete_new.sample(10, random_state = 210)
# Out:
#                          name  born_date               born_city  \
# athlete_id
# 43325          Homero Laddaga 1941-09-10                     NaN
# 141682             Li Mengwen 1995-03-28                  Suzhou
# 7155                Tiit Sokk 1964-11-15                   Tartu
# 85319        Christof Duffner 1971-12-16  Triberg im Schwarzwald
# 46208         Gabrijela Ujčić 1976-10-02                  Rijeka
# 132080         Lauren Kieffer 1987-06-06            Mount Carmel
# 54427            Yu Seung-Hun 1969-10-09                     NaN
# 112520        Clemens Doppler 1980-09-06  Kirchdorf an der Krems
# 88945       Ekundayo Williams 1977-11-23                     NaN
# 73486        Adolfo Clouthier 1909-03-15                Culiacán
#
#                             born_region born_country  \
# athlete_id
# 43325                               NaN          NaN
# 141682                          Jiangsu          CHN
# 7155                           Tartumaa          EST
# 85319                 Baden-Württemberg          GER
# 46208       Primorsko-goranska županija          CRO
# 132080                         Illinois          USA
# 54427                               NaN          NaN
# 112520                   Oberösterreich          AUT
# 88945                               NaN          NaN
# 73486                           Sinaloa          MEX
#
#                                    NOC  height_cm  weight_kg   died_date  \
# athlete_id
# 43325                           Mexico      172.0       84.0         NaN
# 141682      People's Republic of China        NaN        NaN         NaN
# 7155                      Soviet Union      192.0       99.0         NaN
# 85319                          Germany      184.0       66.0         NaN
# 46208                          Croatia        NaN        NaN         NaN
# 132080                   United States      178.0       68.0         NaN
# 54427                Republic of Korea      176.0       75.0         NaN
# 112520                         Austria      200.0       87.0         NaN
# 88945                     Sierra Leone        NaN        NaN         NaN
# 73486                           Mexico      178.0        NaN  2001-04-12
#
#            first_name  born_year  is_tall1 is_tall2
# athlete_id
# 43325          Homero     1941.0     False  Average
# 141682             Li     1995.0     False    Short
# 7155             Tiit     1964.0      True     Tall
# 85319        Christof     1971.0     False  Average
# 46208       Gabrijela     1976.0     False    Short
# 132080         Lauren     1987.0     False  Average
# 54427              Yu     1969.0     False  Average
# 112520        Clemens     1980.0      True     Tall
# 88945        Ekundayo     1977.0     False    Short
# 73486          Adolfo     1909.0     False  Average

# %%
def categorize_weight(row):
  if row['weight_kg'] > 120:
    return 'Heavy'
  elif row['weight_kg'] > 80:
    return 'Medium'
  else:
    return 'Light'

# %%
athlete_new['is_weight'] = athlete_new.apply(categorize_weight, axis=1)

# %%
athlete_new.sample(10, random_state = 210)
# Out:
#                          name  born_date               born_city  \
# athlete_id
# 43325          Homero Laddaga 1941-09-10                     NaN
# 141682             Li Mengwen 1995-03-28                  Suzhou
# 7155                Tiit Sokk 1964-11-15                   Tartu
# 85319        Christof Duffner 1971-12-16  Triberg im Schwarzwald
# 46208         Gabrijela Ujčić 1976-10-02                  Rijeka
# 132080         Lauren Kieffer 1987-06-06            Mount Carmel
# 54427            Yu Seung-Hun 1969-10-09                     NaN
# 112520        Clemens Doppler 1980-09-06  Kirchdorf an der Krems
# 88945       Ekundayo Williams 1977-11-23                     NaN
# 73486        Adolfo Clouthier 1909-03-15                Culiacán
#
#                             born_region born_country  \
# athlete_id
# 43325                               NaN          NaN
# 141682                          Jiangsu          CHN
# 7155                           Tartumaa          EST
# 85319                 Baden-Württemberg          GER
# 46208       Primorsko-goranska županija          CRO
# 132080                         Illinois          USA
# 54427                               NaN          NaN
# 112520                   Oberösterreich          AUT
# 88945                               NaN          NaN
# 73486                           Sinaloa          MEX
#
#                                    NOC  height_cm  weight_kg   died_date  \
# athlete_id
# 43325                           Mexico      172.0       84.0         NaN
# 141682      People's Republic of China        NaN        NaN         NaN
# 7155                      Soviet Union      192.0       99.0         NaN
# 85319                          Germany      184.0       66.0         NaN
# 46208                          Croatia        NaN        NaN         NaN
# 132080                   United States      178.0       68.0         NaN
# 54427                Republic of Korea      176.0       75.0         NaN
# 112520                         Austria      200.0       87.0         NaN
# 88945                     Sierra Leone        NaN        NaN         NaN
# 73486                           Mexico      178.0        NaN  2001-04-12
#
#            first_name  born_year  is_tall1 is_tall2 is_weight
# athlete_id
# 43325          Homero     1941.0     False  Average    Medium
# 141682             Li     1995.0     False    Short     Light
# 7155             Tiit     1964.0      True     Tall    Medium
# 85319        Christof     1971.0     False  Average     Light
# 46208       Gabrijela     1976.0     False    Short     Light
# 132080         Lauren     1987.0     False  Average     Light
# 54427              Yu     1969.0     False  Average     Light
# 112520        Clemens     1980.0      True     Tall    Medium
# 88945        Ekundayo     1977.0     False    Short     Light
# 73486          Adolfo     1909.0     False  Average     Light

# %%
# Saving my data to a csv file

# athlete_new.to_csv("athlete", index = False)

# %% [markdown]
# # Merging and Concatenating Data.

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
nocs = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# Merging
athlete_new = pd.merge(athlete, nocs, left_on='born_country', right_on='NOC', how='left')

# %%
athlete_new.head()
# Out:
#                     name   born_date    born_city           born_region  \
# 0  Jean-François Blanchy  1886-12-12     Bordeaux               Gironde
# 1         Arnaud Boetsch  1969-04-01       Meulan              Yvelines
# 2           Jean Borotra  1898-08-13     Biarritz  Pyrénées-Atlantiques
# 3        Jacques Brugnon  1895-05-11  Paris VIIIe                 Paris
# 4           Albert Canet  1878-04-17   Wandsworth               England
#
#   born_country   NOC_x  height_cm  weight_kg   died_date NOC_y  region notes
# 0          FRA  France        NaN        NaN  1960-10-02   FRA  France   NaN
# 1          FRA  France      183.0       76.0         NaN   FRA  France   NaN
# 2          FRA  France      183.0       76.0  1994-07-17   FRA  France   NaN
# 3          FRA  France      168.0       64.0  1978-03-20   FRA  France   NaN
# 4          GBR  France        NaN        NaN  1930-07-25   GBR      UK   NaN

# %%
athlete_new.rename(columns={'region':'born_country_all'}, inplace=True)

# %%
athlete_new.head()
# Out:
#                     name   born_date    born_city           born_region  \
# 0  Jean-François Blanchy  1886-12-12     Bordeaux               Gironde
# 1         Arnaud Boetsch  1969-04-01       Meulan              Yvelines
# 2           Jean Borotra  1898-08-13     Biarritz  Pyrénées-Atlantiques
# 3        Jacques Brugnon  1895-05-11  Paris VIIIe                 Paris
# 4           Albert Canet  1878-04-17   Wandsworth               England
#
#   born_country   NOC_x  height_cm  weight_kg   died_date NOC_y  \
# 0          FRA  France        NaN        NaN  1960-10-02   FRA
# 1          FRA  France      183.0       76.0         NaN   FRA
# 2          FRA  France      183.0       76.0  1994-07-17   FRA
# 3          FRA  France      168.0       64.0  1978-03-20   FRA
# 4          GBR  France        NaN        NaN  1930-07-25   GBR
#
#   born_country_all notes
# 0           France   NaN
# 1           France   NaN
# 2           France   NaN
# 3           France   NaN
# 4               UK   NaN

# %%
athlete_new[athlete_new['NOC_x'] != athlete_new['born_country_all']]
# Out:
#                        name   born_date         born_city  \
# 4              Albert Canet  1878-04-17        Wandsworth
# 12                J. Defert         NaN               NaN
# 13           Étienne Durand         NaN               NaN
# 16               Guy Forget  1965-01-04        Casablanca
# 27       Guy, Baron Lejeune         NaN               NaN
# ...                     ...         ...               ...
# 145491        Matthew Wepke  1989-12-05               NaN
# 145493   Landysh Falyakhova  1998-08-31  Dva Polya Artash
# 145495    Polina Luchnikova  2002-01-30             Serov
# 145496  Valeriya Merkusheva  1999-09-20   Moskva (Moscow)
# 145497      Yuliya Smirnova  1998-05-08            Kotlas
#
#                  born_region born_country    NOC_x  height_cm  weight_kg  \
# 4                    England          GBR   France        NaN        NaN
# 12                       NaN          NaN   France        NaN        NaN
# 13                       NaN          NaN   France        NaN        NaN
# 16         Casablanca-Settat          MAR   France      189.0       79.0
# 27                       NaN          NaN   France        NaN        NaN
# ...                      ...          ...      ...        ...        ...
# 145491                   NaN          NaN  Jamaica        NaN        NaN
# 145493  Respublika Tatarstan          RUS      ROC        NaN        NaN
# 145495            Sverdlovsk          RUS      ROC      167.0       61.0
# 145496                Moskva          RUS      ROC      168.0       65.0
# 145497           Arkhangelsk          RUS      ROC      163.0       55.0
#
#          died_date NOC_y born_country_all notes
# 4       1930-07-25   GBR               UK   NaN
# 12             NaN   NaN              NaN   NaN
# 13             NaN   NaN              NaN   NaN
# 16             NaN   MAR          Morocco   NaN
# 27             NaN   NaN              NaN   NaN
# ...            ...   ...              ...   ...
# 145491         NaN   NaN              NaN   NaN
# 145493         NaN   RUS           Russia   NaN
# 145495         NaN   RUS           Russia   NaN
# 145496         NaN   RUS           Russia   NaN
# 145497         NaN   RUS           Russia   NaN
#
# [73210 rows x 12 columns]

# %%
# Concatenating

egy = athlete_new[athlete_new['born_country'] == 'EGY'].copy()
irq = athlete_new[athlete_new['born_country'] == 'IRQ'].copy()
display(egy.head())
display(irq.head())
# Out:
#                          name   born_date                    born_city  \
# 185       Avgoustos Zerlentis  1886-11-05  Al-Iskanderiya (Alexandria)
# 1244  Hassan Nour-el-Din Aman  1943-05-07            Al-Qahira (Cairo)
# 1802       Fathi Abdel Rahman  1932-04-16            Al-Qahira (Cairo)
# 1804        Ibrahim Abdrabbou  1925-01-24  Al-Iskanderiya (Alexandria)
# 1805             Gharib Afifi         NaN            Al-Qahira (Cairo)
#
#          born_region born_country       NOC_x  height_cm  weight_kg  \
# 185   Al-Iskanderiya          EGY      Greece        NaN        NaN
# 1244       Al-Qahira          EGY  Chad Egypt      178.0       81.0
# 1802       Al-Qahira          EGY       Egypt        NaN        NaN
# 1804  Al-Iskanderiya          EGY       Egypt        NaN        NaN
# 1805       Al-Qahira          EGY       Egypt        NaN        NaN
#
#        died_date NOC_y born_country_all notes
# 185   1954-01-01   EGY            Egypt   NaN
# 1244         NaN   EGY            Egypt   NaN
# 1802         NaN   EGY            Egypt   NaN
# 1804         NaN   EGY            Egypt   NaN
# 1805  1990-01-01   EGY            Egypt   NaN
#                   name   born_date born_city born_region born_country  \
# 41       Gillian Clark  1961-09-02   Baghdad     Baghdad          IRQ
# 4015  Taha Abdul Karim  1939-12-11   Baghdad     Baghdad          IRQ
# 4018  Khalid Al-Karkhi  1940-08-15   Baghdad     Baghdad          IRQ
# 6222     George Hallaq  1928-05-13   Baghdad     Baghdad          IRQ
# 7284      Wadud Khalil  1927-01-01   Baghdad     Baghdad          IRQ
#
#               NOC_x  height_cm  weight_kg   died_date NOC_y born_country_all  \
# 41    Great Britain      176.0       68.0         NaN   IRQ             Iraq
# 4015           Iraq      156.0       59.0         NaN   IRQ             Iraq
# 4018           Iraq      165.0       63.0         NaN   IRQ             Iraq
# 6222           Iraq        NaN        NaN  2019-05-03   IRQ             Iraq
# 7284           Iraq        NaN        NaN         NaN   IRQ             Iraq
#
#      notes
# 41     NaN
# 4015   NaN
# 4018   NaN
# 6222   NaN
# 7284   NaN

# %%
egy_irq = pd.concat([egy, irq])

# %%
display(egy_irq.head())
display(egy_irq.tail())
# Out:
#                          name   born_date                    born_city  \
# 185       Avgoustos Zerlentis  1886-11-05  Al-Iskanderiya (Alexandria)
# 1244  Hassan Nour-el-Din Aman  1943-05-07            Al-Qahira (Cairo)
# 1802       Fathi Abdel Rahman  1932-04-16            Al-Qahira (Cairo)
# 1804        Ibrahim Abdrabbou  1925-01-24  Al-Iskanderiya (Alexandria)
# 1805             Gharib Afifi         NaN            Al-Qahira (Cairo)
#
#          born_region born_country       NOC_x  height_cm  weight_kg  \
# 185   Al-Iskanderiya          EGY      Greece        NaN        NaN
# 1244       Al-Qahira          EGY  Chad Egypt      178.0       81.0
# 1802       Al-Qahira          EGY       Egypt        NaN        NaN
# 1804  Al-Iskanderiya          EGY       Egypt        NaN        NaN
# 1805       Al-Qahira          EGY       Egypt        NaN        NaN
#
#        died_date NOC_y born_country_all notes
# 185   1954-01-01   EGY            Egypt   NaN
# 1244         NaN   EGY            Egypt   NaN
# 1802         NaN   EGY            Egypt   NaN
# 1804         NaN   EGY            Egypt   NaN
# 1805  1990-01-01   EGY            Egypt   NaN
#                           name   born_date          born_city born_region  \
# 131738         Mohammed Riyadh  1994-02-20            Baghdad     Baghdad
# 131739  Salwan Jasim Al-Aifuri  1991-09-26              Wasit       Wasit
# 138941          Aker Al-Obaidi  1999-09-21              Mosul      Ninawa
# 139136          Dina Ellermann  1980-12-20            Baghdad     Baghdad
# 139896       Ammar Abduljabbar  1995-10-01  Al-Basrah (Basra)   Al-Basrah
#
#        born_country                 NOC_x  height_cm  weight_kg died_date  \
# 131738          IRQ                  Iraq      181.0       75.0       NaN
# 131739          IRQ                  Iraq      180.0      104.0       NaN
# 138941          IRQ  Refugee Olympic Team        NaN        NaN       NaN
# 139136          IRQ               Estonia        NaN        NaN       NaN
# 139896          IRQ               Germany      180.0       91.0       NaN
#
#        NOC_y born_country_all notes
# 131738   IRQ             Iraq   NaN
# 131739   IRQ             Iraq   NaN
# 138941   IRQ             Iraq   NaN
# 139136   IRQ             Iraq   NaN
# 139896   IRQ             Iraq   NaN

# %% [markdown]
# # Handling Null values.

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[[0, 1], 'Units Sold'] = None
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso         NaN
# 1     Monday       Latte         NaN
# 2    Tuesday    Espresso        30.0
# 3    Tuesday       Latte        20.0
# 4  Wednesday    Espresso        35.0

# %%
coffee.loc[coffee['Coffee Type'] == 'Latte', 'price'] = 5.99
coffee.loc[coffee['Coffee Type'] == 'Espresso', 'price'] = 3.99
coffee['revenue'] = coffee['Units Sold'] * coffee['price']

# %%
coffee  # I notice that there are NaN values in the 'Units Sold' column.
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   3.99      NaN
# 1      Monday       Latte         NaN   5.99      NaN
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
# Fill null values with the mean of other related values.
coffee.fillna(coffee['Units Sold'].mean(), inplace = True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan
coffee.loc[4, "Units Sold"] = 25
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   5.99   119.80
# 4   Wednesday    Espresso        25.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
# Fulling null values according to related values.
coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan
coffee.loc[10, 'price'] = np.nan
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   5.99   119.80
# 4   Wednesday    Espresso        25.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0    NaN   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.dropna()  # This will drop all the rows with nan values.  --> I can make 'inplace=True'
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 4   Wednesday    Espresso        25.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.dropna(subset=['Units Sold'])  # This will drop all the rows with nan values in 'Units Sold' column only.  --> I can make 'inplace=True'
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 4   Wednesday    Espresso        25.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0    NaN   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   5.99   119.80
# 4   Wednesday    Espresso        25.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0    NaN   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
display(coffee[coffee['Units Sold'].isna()])  # displaying 'NaN' values in 'Units Sold' rows.
display(coffee[coffee['Units Sold'].notna()])  # displaying 'not NaN' values in 'Units Sold' rows.
# Out:
#        Day Coffee Type  Units Sold  price  revenue
# 2  Tuesday    Espresso         NaN   3.99    119.7
# 3  Tuesday       Latte         NaN   5.99    119.8
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    35.00
# 1      Monday       Latte        35.0   5.99    35.00
# 4   Wednesday    Espresso        25.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0    NaN   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %% [markdown]
# # Aggregating Data.

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
athlete['NOC'].value_counts()
# Out:
# NOC
# United States                 10114
# Great Britain                  6421
# France                         6339
# Canada                         5276
# Italy                          5189
#                               ...
# Azerbaijan North Macedonia        1
# Armenia Bulgaria                  1
# Armenia Kazakhstan                1
# Australia Soviet Union            1
# Austria Czechia                   1
# Name: count, Length: 696, dtype: int64

# %%
athlete[(athlete['born_country'] == 'EGY') & (athlete['died_date' ]!= np.nan)]['born_region'].value_counts()
# Out:
# born_region
# Al-Qahira           286
# Al-Iskanderiya      152
# Al-Jizah             44
# Al-Gharbiyah         22
# Al-Sharqiyah         18
# Bur Said             15
# Ad-Daqahliyah        12
# Beni Suef             7
# As-Suways             7
# Asyut                 6
# Al-Ismailiyah         6
# Al-Buhayrah           5
# Dumyat                5
# Kafr As-Sayh          5
# Al-Fayyum             5
# Qalyubiyah            4
# Al-Minufiyya          3
# Al-Minya              3
# Aswan                 2
# Al-Wadi Al-Jadid      2
# Sawhag                1
# Qina                  1
# Shamal Sina           1
# Ganub Sina            1
# Name: count, dtype: int64

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.loc[coffee['Coffee Type'] == 'Latte', 'price'] = 5.99
coffee.loc[coffee['Coffee Type'] == 'Espresso', 'price'] = 3.99
coffee['revenue'] = coffee['Units Sold'] * coffee['price']
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
coffee.groupby(['Coffee Type'])['revenue'].sum()
# Out:
# Coffee Type
# Espresso    1057.35
# Latte       1168.05
# Name: revenue, dtype: float64

# %%
coffee.groupby(['Day'])['Units Sold'].mean()
# Out:
# Day
# Friday       40.0
# Monday       20.0
# Saturday     40.0
# Sunday       40.0
# Thursday     35.0
# Tuesday      25.0
# Wednesday    30.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Day']).agg({'price': 'sum', 'revenue': 'mean'})
# Out:
#            price  revenue
# Day
# Friday      9.98   194.60
# Monday      9.98    94.80
# Saturday    9.98   194.60
# Sunday      9.98   194.60
# Thursday    9.98   169.65
# Tuesday     9.98   119.75
# Wednesday   9.98   144.70

# %%
coffee.groupby(['Day', 'Coffee Type'])['revenue'].mean()
# Out:
# Day        Coffee Type
# Friday     Espresso       179.55
#            Latte          209.65
# Monday     Espresso        99.75
#            Latte           89.85
# Saturday   Espresso       179.55
#            Latte          209.65
# Sunday     Espresso       179.55
#            Latte          209.65
# Thursday   Espresso       159.60
#            Latte          179.70
# Tuesday    Espresso       119.70
#            Latte          119.80
# Wednesday  Espresso       139.65
#            Latte          149.75
# Name: revenue, dtype: float64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='revenue')
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   89.85
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday        119.70  119.80
# Wednesday      139.65  149.75

# %%
display(pivot.loc['Friday', 'Latte'])
display(pivot.sum())
# Out:
# 209.65
# Coffee Type
# Espresso    1057.35
# Latte       1168.05
# dtype: float64

# %%
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
athlete['born_date'] = pd.to_datetime(athlete['born_date'])

# %%
athlete.groupby(athlete['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %% [markdown]
# # Advanced Functionality.

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.loc[coffee['Coffee Type'] == 'Latte', 'price'] = 5.99
coffee.loc[coffee['Coffee Type'] == 'Espresso', 'price'] = 3.99
coffee['revenue'] = coffee['Units Sold'] * coffee['price']
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift(2)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue
# 0      Monday    Espresso          25   3.99    99.75                NaN
# 1      Monday       Latte          15   5.99    89.85                NaN
# 2     Tuesday    Espresso          30   3.99   119.70              99.75
# 3     Tuesday       Latte          20   5.99   119.80              89.85
# 4   Wednesday    Espresso          35   3.99   139.65             119.70
# 5   Wednesday       Latte          25   5.99   149.75             119.80
# 6    Thursday    Espresso          40   3.99   159.60             139.65
# 7    Thursday       Latte          30   5.99   179.70             149.75
# 8      Friday    Espresso          45   3.99   179.55             159.60
# 9      Friday       Latte          35   5.99   209.65             179.70
# 10   Saturday    Espresso          45   3.99   179.55             179.55
# 11   Saturday       Latte          35   5.99   209.65             209.65
# 12     Sunday    Espresso          45   3.99   179.55             179.55
# 13     Sunday       Latte          35   5.99   209.65             209.65

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue
# 0      Monday    Espresso          25   3.99    99.75                NaN
# 1      Monday       Latte          15   5.99    89.85                NaN
# 2     Tuesday    Espresso          30   3.99   119.70              99.75
# 3     Tuesday       Latte          20   5.99   119.80              89.85
# 4   Wednesday    Espresso          35   3.99   139.65             119.70
# 5   Wednesday       Latte          25   5.99   149.75             119.80
# 6    Thursday    Espresso          40   3.99   159.60             139.65
# 7    Thursday       Latte          30   5.99   179.70             149.75
# 8      Friday    Espresso          45   3.99   179.55             159.60
# 9      Friday       Latte          35   5.99   209.65             179.70
# 10   Saturday    Espresso          45   3.99   179.55             179.55
# 11   Saturday       Latte          35   5.99   209.65             209.65
# 12     Sunday    Espresso          45   3.99   179.55             179.55
# 13     Sunday       Latte          35   5.99   209.65             209.65

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
athlete['height_rank'] = athlete['height_cm'].rank()
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date  height_rank
# athlete_id
# 1           1960-10-02          NaN
# 2                  NaN      79054.5
# 3           1994-07-17      79054.5
# 4           1978-03-20      22677.0
# 5           1930-07-25          NaN

# %%
athlete.sort_values(['height_rank'], ascending=False)
# Out:
#                              name   born_date           born_city  \
# athlete_id
# 89782                    Yao Ming  1980-09-12      Xuhui District
# 5804               Tommy Burleson  1952-02-24           Crossnore
# 7013              Arvydas Sabonis  1964-12-19              Kaunas
# 89787              Roberto Dueñas  1975-11-01              Madrid
# 122147               Zhang Zhaoxu  1987-11-18             Binzhou
# ...                           ...         ...                 ...
# 149217                Sin Ye-Chan  1995-06-13                 NaN
# 149218              Matthew Wepke  1989-12-05                 NaN
# 149219      Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 149220         Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 149814              Bill Phillips  1913-07-15        Dulwich Hill
#
#                      born_region born_country                         NOC  \
# athlete_id
# 89782                   Shanghai          CHN  People's Republic of China
# 5804              North Carolina          USA               United States
# 7013                      Kaunas          LTU      Lithuania Soviet Union
# 89787                     Madrid          ESP                       Spain
# 122147                  Shandong          CHN  People's Republic of China
# ...                          ...          ...                         ...
# 149217                       NaN          NaN           Republic of Korea
# 149218                       NaN          NaN                     Jamaica
# 149219       Ciudad de La Habana          CUB                        Cuba
# 149220      Respublika Tatarstan          RUS                         ROC
# 149814           New South Wales          AUS                   Australia
#
#             height_cm  weight_kg   died_date  height_rank
# athlete_id
# 89782           226.0      141.0         NaN     106651.0
# 5804            223.0      102.0         NaN     106649.5
# 7013            223.0      122.0         NaN     106649.5
# 89787           221.0      137.0         NaN     106647.0
# 122147          221.0      110.0         NaN     106647.0
# ...               ...        ...         ...          ...
# 149217            NaN        NaN         NaN          NaN
# 149218            NaN        NaN         NaN          NaN
# 149219            NaN        NaN  2019-11-24          NaN
# 149220            NaN        NaN         NaN          NaN
# 149814            NaN        NaN  2003-10-20          NaN
#
# [145500 rows x 10 columns]

# %%
# Cumulative summing.
coffee['cumulative_sum'] = coffee['revenue'].cumsum()
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso          25   3.99    99.75                NaN
# 1      Monday       Latte          15   5.99    89.85                NaN
# 2     Tuesday    Espresso          30   3.99   119.70              99.75
# 3     Tuesday       Latte          20   5.99   119.80              89.85
# 4   Wednesday    Espresso          35   3.99   139.65             119.70
# 5   Wednesday       Latte          25   5.99   149.75             119.80
# 6    Thursday    Espresso          40   3.99   159.60             139.65
# 7    Thursday       Latte          30   5.99   179.70             149.75
# 8      Friday    Espresso          45   3.99   179.55             159.60
# 9      Friday       Latte          35   5.99   209.65             179.70
# 10   Saturday    Espresso          45   3.99   179.55             179.55
# 11   Saturday       Latte          35   5.99   209.65             209.65
# 12     Sunday    Espresso          45   3.99   179.55             179.55
# 13     Sunday       Latte          35   5.99   209.65             209.65
#
#     cumulative_sum
# 0            99.75
# 1           189.60
# 2           309.30
# 3           429.10
# 4           568.75
# 5           718.50
# 6           878.10
# 7          1057.80
# 8          1237.35
# 9          1447.00
# 10         1626.55
# 11         1836.20
# 12         2015.75
# 13         2225.40

# %%
latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()
latte
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 1      Monday       Latte          15   5.99    89.85                NaN
# 3     Tuesday       Latte          20   5.99   119.80              89.85
# 5   Wednesday       Latte          25   5.99   149.75             119.80
# 7    Thursday       Latte          30   5.99   179.70             149.75
# 9      Friday       Latte          35   5.99   209.65             179.70
# 11   Saturday       Latte          35   5.99   209.65             209.65
# 13     Sunday       Latte          35   5.99   209.65             209.65
#
#     cumulative_sum
# 1            189.6
# 3            429.1
# 5            718.5
# 7           1057.8
# 9           1447.0
# 11          1836.2
# 13          2225.4

# %%
latte['3days_sold'] = latte['Units Sold'].rolling(3).sum()
latte
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 1      Monday       Latte          15   5.99    89.85                NaN
# 3     Tuesday       Latte          20   5.99   119.80              89.85
# 5   Wednesday       Latte          25   5.99   149.75             119.80
# 7    Thursday       Latte          30   5.99   179.70             149.75
# 9      Friday       Latte          35   5.99   209.65             179.70
# 11   Saturday       Latte          35   5.99   209.65             209.65
# 13     Sunday       Latte          35   5.99   209.65             209.65
#
#     cumulative_sum  3days_sold
# 1            189.6         NaN
# 3            429.1         NaN
# 5            718.5        60.0
# 7           1057.8        75.0
# 9           1447.0        90.0
# 11          1836.2       100.0
# 13          2225.4       105.0

# %%
results_numpy = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.csv')  # This was in Pandas 1.0
results_arrow = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.csv', engine = 'pyarrow', dtype_backend='pyarrow')  # This is now in Pandas 2.0

# %%
display(results_numpy.head())
display(results_numpy.info())
display(results_arrow.info())
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB
# None

# %% [markdown]
# # Applying on an existance file. 'Coffee Shop.csv'

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.loc[coffee['Coffee Type'] == 'Latte', 'price'] = 5.99
coffee.loc[coffee['Coffee Type'] == 'Espresso', 'price'] = 3.99
coffee['revenue'] = coffee['Units Sold'] * coffee['price']
coffee

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(1)
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 464.0+ bytes

# %%
coffee.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
coffee.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold'], dtype='object')

# %%
coffee.sort_values('Units Sold')
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values('Units Sold', ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
display(coffee.sort_values(['Units Sold', 'Coffee Type'], ascending=[0, 1]))
display(coffee.sort_values(['Units Sold', 'Coffee Type'], ascending=[1, 0]))
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in coffee.iterrows():
  print(index)
  print(row)
  print('\n\n\n')
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
#
#
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
#
#
#
#
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
#
#
#
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
#
#
#
#
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
#
#
#
#
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object

# %%
coffee.nunique()  # Getting number of unique elements for each column.
# Out:
# Day            7
# Coffee Type    2
# Units Sold     7
# dtype: int64

# %%
coffee['Coffee Type'].unique()
# Out:
# array(['Espresso', 'Latte'], dtype=object)

# %%
coffee_excel = coffee.to_excel('coffee.xlsx')  # Converting the file to excel file.

# %% [markdown]
# # Applying on an existance file. 'Athletics.csv'

# %%
athlete = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv').set_index('athlete_id')
athlete.head()
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25

# %%
athlete.tail()
# Out:
#                            name   born_date        born_city      born_region  \
# athlete_id
# 149222        Polina Luchnikova  2002-01-30            Serov       Sverdlovsk
# 149223      Valeriya Merkusheva  1999-09-20  Moskva (Moscow)           Moskva
# 149224          Yuliya Smirnova  1998-05-08           Kotlas      Arkhangelsk
# 149225           André Foussard  1899-05-19            Niort      Deux-Sèvres
# 149814            Bill Phillips  1913-07-15     Dulwich Hill  New South Wales
#
#            born_country        NOC  height_cm  weight_kg   died_date
# athlete_id
# 149222              RUS        ROC      167.0       61.0         NaN
# 149223              RUS        ROC      168.0       65.0         NaN
# 149224              RUS        ROC      163.0       55.0         NaN
# 149225              FRA     France      166.0        NaN  1986-03-18
# 149814              AUS  Australia        NaN        NaN  2003-10-20

# %%
display(athlete.sample(5))  # Gettnig a random '10' samples.
display(athlete.sample(5, random_state=122))  # This will print the same rows unless I change the number '122'.
# Out:
#                        name   born_date      born_city          born_region  \
# athlete_id
# 70532       Rüdiger Stenzel  1968-04-16  Gelsenkirchen  Nordrhein-Westfalen
# 50062       Vladimir Selkov  1971-04-01      Berezniki            Perm Kray
# 14954           Fritz Joost  1954-07-14            NaN                  NaN
# 112599           Yang Xiuli  1983-09-01          Fuxin             Liaoning
# 57910        Kaarlo Koskelo  1888-04-12            NaN                  NaN
#
#            born_country                              NOC  height_cm  \
# athlete_id
# 70532               GER                          Germany      180.0
# 50062               RUS  Russian Federation Unified Team      188.0
# 14954               NaN                      Switzerland      181.0
# 112599              CHN       People's Republic of China      173.0
# 57910               NaN                          Finland      172.0
#
#             weight_kg   died_date
# athlete_id
# 70532            65.0         NaN
# 50062            75.0         NaN
# 14954            72.0         NaN
# 112599           77.0         NaN
# 57910             NaN  1953-12-21
#                          name   born_date      born_city born_region  \
# athlete_id
# 58157             Eddie Bowey  1928-01-05         London     England
# 65816               Jane Bell  1910-06-02        Toronto     Ontario
# 26145       Beniamino Vignola  1959-06-12         Verona      Verona
# 66053         Lionel Fournier  1917-03-19  Pincher Creek     Alberta
# 97498        Hiroyasu Shimizu  1974-02-27        Obihiro    Hokkaido
#
#            born_country            NOC  height_cm  weight_kg   died_date
# athlete_id
# 58157               GBR  Great Britain        NaN        NaN  2016-01-01
# 65816               CAN         Canada      169.0       58.0  1998-07-01
# 26145               ITA          Italy      172.0       64.0         NaN
# 66053               CAN         Canada        NaN        NaN  1993-09-03
# 97498               JPN          Japan      162.0       70.0         NaN

# %%
display(athlete.loc[[1, 2, 3]])
display(athlete.loc[1:6])
display(athlete.loc[[1, 2, 3], ['name']])
display(athlete.loc[[1, 2, 3], ['name', 'born_city']])

display(athlete.iloc[[0, 1, 2], [0, 1, 2]])
display(athlete.iloc[1:3, 0:3])
# Out:
#                              name   born_date born_city           born_region  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12  Bordeaux               Gironde
# 2                  Arnaud Boetsch  1969-04-01    Meulan              Yvelines
# 3                    Jean Borotra  1898-08-13  Biarritz  Pyrénées-Atlantiques
#
#            born_country     NOC  height_cm  weight_kg   died_date
# athlete_id
# 1                   FRA  France        NaN        NaN  1960-10-02
# 2                   FRA  France      183.0       76.0         NaN
# 3                   FRA  France      183.0       76.0  1994-07-17
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
# 6               Nicolas Chatelain  1970-01-13       Amiens
#
#                      born_region born_country     NOC  height_cm  weight_kg  \
# athlete_id
# 1                        Gironde          FRA  France        NaN        NaN
# 2                       Yvelines          FRA  France      183.0       76.0
# 3           Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 4                          Paris          FRA  France      168.0       64.0
# 5                        England          GBR  France        NaN        NaN
# 6                          Somme          FRA  France      181.0       70.0
#
#              died_date
# athlete_id
# 1           1960-10-02
# 2                  NaN
# 3           1994-07-17
# 4           1978-03-20
# 5           1930-07-25
# 6                  NaN
#                              name
# athlete_id
# 1           Jean-François Blanchy
# 2                  Arnaud Boetsch
# 3                    Jean Borotra
#                              name born_city
# athlete_id
# 1           Jean-François Blanchy  Bordeaux
# 2                  Arnaud Boetsch    Meulan
# 3                    Jean Borotra  Biarritz
#                              name   born_date born_city
# athlete_id
# 1           Jean-François Blanchy  1886-12-12  Bordeaux
# 2                  Arnaud Boetsch  1969-04-01    Meulan
# 3                    Jean Borotra  1898-08-13  Biarritz
#                       name   born_date born_city
# athlete_id
# 2           Arnaud Boetsch  1969-04-01    Meulan
# 3             Jean Borotra  1898-08-13  Biarritz

# %%
athlete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145500 entries, 1 to 149814
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          145500 non-null  object
#  1   born_date     143693 non-null  object
#  2   born_city     110908 non-null  object
#  3   born_region   110908 non-null  object
#  4   born_country  110908 non-null  object
#  5   NOC           145499 non-null  object
#  6   height_cm     106651 non-null  float64
#  7   weight_kg     102070 non-null  float64
#  8   died_date     33940 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 15.1+ MB

# %%
athlete.describe()
# Out:
#            height_cm      weight_kg
# count  106651.000000  102070.000000
# mean      176.333724      71.890996
# std        10.380282      14.465540
# min       127.000000      25.000000
# 25%       170.000000      62.000000
# 50%       176.000000      70.000000
# 75%       183.000000      80.000000
# max       226.000000     198.000000

# %% [markdown]
# # Applying on an existance file. 'results.parquet'

# %%
# olympics_results = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.parquet')   # Can't be decoded because it is large.
# olympics_results.head()
